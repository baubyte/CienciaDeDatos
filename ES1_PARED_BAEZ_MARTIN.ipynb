# %% [markdown]
# <a href="https://colab.research.google.com/github/baubyte/CienciaDeDatos/blob/main/ES1_PARED_BAEZ_MARTIN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Licenciatura en Ciencia de Datos
#
# ## Unidad 1 - Ejercicio 1
#
# **Nombre y Apellido:** Martin Jose Pared Baez
#
# **Materia:** Ciencia de Datos
#
# **Docentes:** Germán Giró, Malena Constancio, Giselle Bustamante
#
# **Fecha:** 21/03/2026
#
# ### Objetivo
#
# Crear un Notebook en la cuenta de Google personal.

# %%
import pandas as pd

# Crear un marco de datos de personas
data = {'Nombre': ['Juan', 'Laura', 'Sara', 'Antonio', 'Luisa'],
        'Edad': [25, 36, 40, 41, 29],
        'Género': ['M', 'F', 'F', 'M', 'F'],
        'Ciudad': ['Rosario', 'Rosario', 'Funes', 'Roldán', 'Rosario']}

df = pd.DataFrame(data)

# Contar los valores únicos de la columna "Género"
conteo_genero = df['Género'].value_counts()

# Agrupar los datos por la columna "Ciudad"
agrupado_ciudad = df.groupby('Ciudad')

# Mostrar los resultados
print("Datos categóricos:")
print(df)
print("\nConteo de género:")
print(conteo_genero)
print("\nAgrupado por ciudad:")
print(agrupado_ciudad["Edad"].mean())
# Out:
# Datos categóricos:
#     Nombre  Edad Género   Ciudad
# 0     Juan    25      M  Rosario
# 1    Laura    36      F  Rosario
# 2     Sara    40      F    Funes
# 3  Antonio    41      M   Roldán
# 4    Luisa    29      F  Rosario
#
# Conteo de género:
# Género
# F    3
# M    2
# Name: count, dtype: int64
#
# Agrupado por ciudad:
# Ciudad
# Funes      40.0
# Roldán     41.0
# Rosario    30.0
# Name: Edad, dtype: float64
